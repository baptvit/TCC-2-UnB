# %% [markdown]
# ## Slipt dataset in a stratified way
#
# train: 75%,
# test: 10%.
# val: 15%
#
# seed: 12345

# %%
import split_folders

# Split with a ratio.
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
split_folders.ratio('/home/helpthx/Documents/Desafio/dataset', output='/home/helpthx/Documents/Desafio/dataset-split', seed=12345, ratio=(.75, .15, .1)) # default values
# Out:
# Copying files: 0 files [00:00, ? files/s]
# Copying files: 1 files [00:00,  4.36 files/s]
# Copying files: 7 files [00:00,  6.03 files/s]
# Copying files: 17 files [00:00,  8.38 files/s]
# Copying files: 25 files [00:00, 11.45 files/s]
# Copying files: 35 files [00:00, 15.54 files/s]
# Copying files: 42 files [00:00, 20.02 files/s]
# Copying files: 51 files [00:00, 25.81 files/s]
# Copying files: 62 files [00:00, 33.33 files/s]
# Copying files: 70 files [00:01, 39.43 files/s]
# Copying files: 80 files [00:01, 47.70 files/s]
# Copying files: 89 files [00:01, 55.43 files/s]
# Copying files: 98 files [00:01, 62.06 files/s]
# Copying files: 112 files [00:01, 74.06 files/s]
# Copying files: 123 files [00:01, 80.79 files/s]
# Copying files: 135 files [00:01, 87.63 files/s]
# Copying files: 146 files [00:01, 86.77 files/s]
# Copying files: 156 files [00:01, 87.86 files/s]
# Copying files: 166 files [00:02, 84.90 files/s]
# Copying files: 176 files [00:02, 81.86 files/s]
# ...
